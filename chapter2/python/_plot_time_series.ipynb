# %%
import pandas as pd
from pandas import DataFrame

# %%
nums = pd.read_csv("../data/time_series.csv")['value']

# %%
moving_averages = pd.Series(nums).rolling(7).mean()

# %%
nums
# Out:
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
#             ...
# 9999995    1428576
# 9999996    1428571
# 9999997    1428572
# 9999998    1428573
# 9999999    1428574
# Name: value, Length: 10000000, dtype: int64

# %%
moving_averages
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#                ...
# 9999995    1.428573e+06
# 9999996    1.428573e+06
# 9999997    1.428573e+06
# 9999998    1.428573e+06
# 9999999    1.428574e+06
# Name: value, Length: 10000000, dtype: float64

# %%
DataFrame({'nums': nums , 'moving_averages': moving_averages })[:100].plot()
# Out:
# <AxesSubplot:>
